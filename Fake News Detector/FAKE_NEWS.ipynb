# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud as wc

from string import punctuation as p, digits as d
from collections import Counter as cnt
from nltk.tokenize import word_tokenize as wt
from nltk.stem import WordNetLemmatizer as wl
from nltk.corpus import stopwords
from gensim import corpora

from sklearn.feature_extraction.text import TfidfVectorizer as tf
from sklearn.model_selection import train_test_split as tts,GridSearchCV as gsv,cross_val_score as cvs

from sklearn.metrics import accuracy_score,classification_report,f1_score,auc,roc_curve,roc_auc_score,confusion_matrix,log_loss,\
precision_score,recall_score,mean_squared_error

from sklearn.linear_model import LogisticRegression,PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from  sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier


import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")

import joblib

# %%
df=pd.read_csv("train_news.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0     id                                           headline  \
# 0           0   9653  Ethics Questions Dogged Agriculture Nominee as...
# 1           1  10041  U.S. Must Dig Deep to Stop Argentina’s Lionel ...
# 2           2  19113  Cotton to House: ’Do Not Walk the Plank and Vo...
# 3           3   6868  Paul LePage, Besieged Maine Governor, Sends Co...
# 4           4   7596                       A Digital 9/11 If Trump Wins
# 5           5   3196  Whatever the Outcome on November 8th the US Wi...
# 6           6   5134  Rapid Evolution Saved This Fish From Pollution...
# 7           7   1504  Alabama Prison Officials Retaliate Against Pri...
# 8           8  13559                                                NaN
# 9           9   4203           Can We Live in a Constant State of Love?
#
#                    written_by  \
# 0  Eric Lipton and Steve Eder
# 1             David Waldstein
# 2                     Pam Key
# 3                Jess Bidgood
# 4           Finian Cunningham
# 5                         NaN
# 6                JoAnna Klein
# 7            Brian Sonenstein
# 8                 steventexas
# 9                     Gillian
#
#                                                 news  label
# 0  WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0
# 1  HOUSTON  —   Venezuela had a plan. It was a ta...      0
# 2  Sunday on ABC’s “This Week,” while discussing ...      0
# 3  AUGUSTA, Me.  —   The beleaguered Republican g...      0
# 4    Finian Cunningham has written extensively on...      1
# 5  Taming the corporate media beast Whatever the ...      1
# 6  The State of New Jersey says you can’t eat the...      0
# 7  Advocates say prison officials at the Kilby Co...      1
# 8  People have made up their minds on president.\...      1
# 9  Leave a reply \nToni Emerson – When we fall in...      1

# %%
print('Shape of the dataset -\n ',df.shape)

print('\nName of columns in the dataset-\n',df.columns.values)
# Out:
# Shape of the dataset -
#   (20800, 6)
#
# Name of columns in the dataset-
#  ['Unnamed: 0' 'id' 'headline' 'written_by' 'news' 'label']

# %%
#checking if there is any duplicated values
print('Number of duplicated values:-',df.duplicated().sum())
# Out:
# Number of duplicated values:- 0

# %%
#checking for null values
for i in df.columns:
    null=df[i].isnull().sum()
    if null>0:
        print('Number of Null Values At Column ',i ,'==  ',null )
    else:
        print('There are no null values in column-',i)
# Out:
# There are no null values in column- Unnamed: 0
# There are no null values in column- id
# Number of Null Values At Column  headline ==   558
# Number of Null Values At Column  written_by ==   1957
# Number of Null Values At Column  news ==   39
# There are no null values in column- label

# %%
#heatmap of null values
sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=0.8)
plt.figure(figsize=(12,4),dpi=120)
sns.heatmap(df.isnull(),cmap='Accent')
plt.show()

# %%
#dropping unwanted columns as we'll be working on the news and labe columns only
#dropping null values

news=df.copy()
news.dropna(inplace=True)
news.drop(['Unnamed: 0','id','headline','written_by'],axis=1,inplace=True)
news.reset_index(inplace=True)

# %%
news['len of uncleaned news']= news['news'].str.len().astype('int64')
news.head(10)
# Out:
#    index                                               news  label  \
# 0      0  WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0
# 1      1  HOUSTON  —   Venezuela had a plan. It was a ta...      0
# 2      2  Sunday on ABC’s “This Week,” while discussing ...      0
# 3      3  AUGUSTA, Me.  —   The beleaguered Republican g...      0
# 4      4    Finian Cunningham has written extensively on...      1
# 5      6  The State of New Jersey says you can’t eat the...      0
# 6      7  Advocates say prison officials at the Kilby Co...      1
# 7      9  Leave a reply \nToni Emerson – When we fall in...      1
# 8     10  BREAKING: Clinton Fixer Reveals Sick Smear Hil...      1
# 9     11  Home › POLITICS | US NEWS › BLOOMBERG-BACKED P...      1
#
#    len of uncleaned news
# 0                   7936
# 1                   6112
# 2                    425
# 3                   6516
# 4                   9164
# 5                   4159
# 6                   6311
# 7                   6386
# 8                   1664
# 9                   2487

# %%
#checking data loss percentage
print('shape of the dataset with null values: ',df.shape)
print('Shape of dataset without any null vallues: ', news.shape)
print('No of rows dropped:', df.shape[0]-news.shape[0])
print('Percentage dropped:',((df.shape[0]-news.shape[0])/df.shape[0])*100)
# Out:
# shape of the dataset with null values:  (20800, 6)
# Shape of dataset without any null vallues:  (18285, 4)
# No of rows dropped: 2515
# Percentage dropped: 12.091346153846153

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18285 entries, 0 to 18284
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  18285 non-null  int64
#  1   news                   18285 non-null  object
#  2   label                  18285 non-null  int64
#  3   len of uncleaned news  18285 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 571.5+ KB

# %%
lb=news['label'].value_counts().index.tolist()
val=news['label'].value_counts().values.tolist()
exp=(0.025,0)
clr=('cyan','skyblue')
plt.figure(figsize=(10,6),dpi=140)
sns.set_context('talk',font_scale=0.4)
sns.set(style='whitegrid')
plt.pie(x=val,explode=exp,labels=lb,colors=clr,autopct='%2.0f%%',pctdistance=0.5, shadow=True,radius=0.9)
plt.legend(["0 = NOT FAKE",'1 = FAKE'])
plt.show()

# %%
#CREATING A FUNCTION TO PERFORM ASERIES OF OPERATIONS

def preprocess(text):
    processed=[]
    lower=text.lower().replace(r'\n'," ").replace(r'\s+', ' ').replace(r'\d+(\.\d+)?', ' ')
    text=lower.replace(r"[^a-zA-Z0-9]+", " ").replace(r"—"," ").replace(r'“', ' ').replace(r'”',' ').replace('’',' ').replace(r'–',' ')
    #removing \n,large white space and leading_trailing white spaces, numbers and special characters by single white space
    
    punct=text.translate(str.maketrans('', '', p))  #remove punctuation
    digit=punct.translate(str.maketrans('', '', d))       #remove digits if any
    word= wt(digit, "english")
    
    for i in word:
        if i not in stopwords.words('english'):
            lemma=wl().lemmatize(i)
            processed.append(lemma)
    return (" ".join([x for x in processed])).strip()

# %%
#TESTING THE FUNCTION CREATED ABOVE
text = 'The chief minister should not have done it because in the Constitution,law and order is a state issue.I had told him not to do so. I told him that he should be the one to decide when to enforce the lockdown. It was a big mistake, but when I talk about it, the BJP says that I have become (Muhammad Ali) Jinnah. Did you have anything to do with Jinnah 70 years ago? The BJP must understand that the followers of Jinnah have gone to Pakistan. We rejected Jinnah and also the “two-nation theory”. They say that I am against Hindus; the BJP has demolished a mosque, we ask for Rs 10 crore for development of a temple in Lal Darwaza” he stated.Telangana BJP President Bandi Sanjay Kumar on Tuesday had said that the Telangana Rashtra Samithi (TRS) and AIMIM Chief were trying to win the GHMC polls with “Rohingyas, Pakistani and Afghanistani voters”. (ANI)..'
print("Original Document: \n",text)


processed=[]

for word in text.split(' '):
    processed.append(word)
print(processed)

print("\n\nTokenized and lemmatized document: \n")
print(preprocess(text))
# Out:
# Original Document:
#  The chief minister should not have done it because in the Constitution,law and order is a state issue.I had told him not to do so. I told him that he should be the one to decide when to enforce the lockdown. It was a big mistake, but when I talk about it, the BJP says that I have become (Muhammad Ali) Jinnah. Did you have anything to do with Jinnah 70 years ago? The BJP must understand that the followers of Jinnah have gone to Pakistan. We rejected Jinnah and also the “two-nation theory”. They say that I am against Hindus; the BJP has demolished a mosque, we ask for Rs 10 crore for development of a temple in Lal Darwaza” he stated.Telangana BJP President Bandi Sanjay Kumar on Tuesday had said that the Telangana Rashtra Samithi (TRS) and AIMIM Chief were trying to win the GHMC polls with “Rohingyas, Pakistani and Afghanistani voters”. (ANI)..
# ['The', 'chief', 'minister', 'should', 'not', 'have', 'done', 'it', 'because', 'in', 'the', 'Constitution,law', 'and', 'order', 'is', 'a', 'state', 'issue.I', 'had', 'told', 'him', 'not', 'to', 'do', 'so.', 'I', 'told', 'him', 'that', 'he', 'should', 'be', 'the', 'one', 'to', 'decide', 'when', 'to', 'enforce', 'the', 'lockdown.', 'It', 'was', 'a', 'big', 'mistake,', 'but', 'when', 'I', 'talk', 'about', 'it,', 'the', 'BJP', 'says', 'that', 'I', 'have', 'become', '(Muhammad', 'Ali)', 'Jinnah.', 'Did', 'you', 'have', 'anything', 'to', 'do', 'with', 'Jinnah', '70', 'years', 'ago?', 'The', 'BJP', 'must', 'understand', 'that', 'the', 'followers', 'of', 'Jinnah', 'have', 'gone', 'to', 'Pakistan.', 'We', 'rejected', 'Jinnah', 'and', 'also', 'the', '“two-nation', 'theory”.', 'They', 'say', 'that', 'I', 'am', 'against', 'Hindus;', 'the', 'BJP', 'has', 'demolished', 'a', 'mosque,', 'we', 'ask', 'for', 'Rs', '10', 'crore', 'for', 'development', 'of', 'a', 'temple', 'in', 'Lal', 'Darwaza”', 'he', 'stated.Telangana', 'BJP', 'President', 'Bandi', 'Sanjay', 'Kumar', 'on', 'Tuesday', 'had', 'said', 'that', 'the', 'Telangana', 'Rashtra', 'Samithi', '(TRS)', 'and', 'AIMIM', 'Chief', 'were', 'trying', 'to', 'win', 'the', 'GHMC', 'polls', 'with', '“Rohingyas,', 'Pakistani', 'and', 'Afghanistani', 'voters”.', '(ANI)..']
#
#
# Tokenized and lemmatized document:
#
# chief minister done constitutionlaw order state issuei told told one decide enforce lockdown big mistake talk bjp say become muhammad ali jinnah anything jinnah year ago bjp must understand follower jinnah gone pakistan rejected jinnah also twonation theory say hindu bjp demolished mosque ask r crore development temple lal darwaza statedtelangana bjp president bandi sanjay kumar tuesday said telangana rashtra samithi trs aimim chief trying win ghmc poll rohingyas pakistani afghanistani voter ani

# %%
news['news'][7]
# Out:
# 'Leave a reply \nToni Emerson – When we fall in love, our heart becomes full of feel-good qualities that infuse our life with joy and excitement. Everything feels light, fresh and more vibrant. We wake up to a brighter day, the air is warmer, the sun is brighter, everything is right with the world. \nLiving life through the interactive and colorful kaleidoscope of love is one of the highest human experiences . Wouldn’t it be fantastic to capture this experience and transform it into a permanent state of being? In my next few articles, we will formulate our unique blueprint to reconnect to our love source and transition from experiences of love which come and go to living love at its fullest moment to moment. Love & Emotions \nUnderstanding the difference between love and the many feelings inspired by love is essential in realizing that love is the baseline from which everything else emerges. \nAs human beings, we experience many emotional states under love’s vast umbrella, yet each one of them fails to convey the totality of what love is. Love is not equal to the sum of its parts. It is far more powerful than transient emotions. It is an integral state of being waiting to be rediscovered. \nEach deeply nourishing emotion ushered by love stands on its own merits and offers its own specific gifts. These emotions assist us in reaching our full potential as human being by deepening our interior faculties and also by giving us the human qualities that propel us into action to help others in need and to make our world a better world. Love’s Ambassadors \nLove’s ambassadors enrich our life experience and increase our range of perception. Love’s ambassadors are: compassion, joy, kindness, wisdom, peace, gratitude, equanimity, appreciation, pleasure, acceptance, intimacy, benevolence, grace, generosity, respect, sympathy, among others. \nAll these supreme heart qualities advocate on behalf of love and fall under its vast umbrella, but none of them define what love is. They suggest what love might feel like, they point in the direction of love, but they individually and collectively do not come close to the full spectrum of love’s power. Each heart quality is unique and offers special gifts. For example, appreciation may feel like love but actually represents a recognition of a certain quality. It has a finite characteristic. So does gratitude which has many uplifting vibrations and is essentially the crystal clear awareness and heartfelt acknowledge-ment of life’s gifts. Compassion, Love’s Favorite Wingman \nMany of these qualities are considered to be divine in nature because they embody the highest human values. Wisdom traditions foster these qualities of the heart while making the distinction between love and its ambassadors, most notably between love and compassion. The tender feeling evoked by compassion is considered to be a universal virtue, one we extend towards ourselves but more frequently towards other people’s suffering. Compassion has a global history with various ways of expression, depending on cultural differences, yet it has held throughout times its distinct benevolent meaning and its position as love’s favorite wingman. \nOne of the Buddhist interpretation of compassion is the desire to relieve sentient beings of suffering, while love is the desire to bring happiness to sentient beings . \nThe Christian tradition holds universal love to be the principal message of Jesus (the Gospels), with many direct references of love in the Bible, and compassion is viewed as the method for enacting this love as part of our responsibility to alleviate human suffering in the world. \nIn Hinduism, all love for others is considered self love as brahma (universal soul) manifested in the individual ( atman ) while seva (selfless service) is a central theme of life, practical compassion in action and our duty to humanity. Love Is A State Of Being \n“I’m not interested in being a “lover.” I’m interested in only being love.” — Ram Dass \nL ...

# %%
# %%time
clean = []

for i in news['news']:
    clean.append(preprocess(i))
# Out:
# Wall time: 37min 13s

# %%
print("Length of cleaned text=\t",len(clean))
print(clean[8])
# Out:
# Length of cleaned text=	 18285
# breaking clinton fixer reveals sick smear hillary ordered monica call talk better leave podesta written pm worried get cheryl end bad place session last till time timely walk unclear clinton needed sobered early day consuming certain medication left woozy puffing marijuana joint drinking booze advertisement story continues simply taking situation seriously whatever needed made understood reality ie sobered used metaphorically known democrat nominee penchant drinking campaign trail like drink amy chozick national political reporter new york time told abc news february six month email sent campaign trail press thought taking shot pander voter pennsylvania um additionally earlier month chozick issued tweet clinton campaign plane claiming nominee wanted take immediately drink served need take drink served hillary say campaign plane httpstcoxrzsehoxwb amy chozick amychozick october clinton may suffer drinking problem certainly heavy drinking campaigning president would indeed problem advertisement story continues

# %%
#USING THE EXTRACTED FEATURE AS news
processed = pd.DataFrame({'cleaned news' : clean })
news['clean_news']= processed

# %%
news['len of cleaned news']=news['clean_news'].str.len().astype('int64')
news.head(5)
# Out:
#    index                                               news  label  \
# 0      0  WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0
# 1      1  HOUSTON  —   Venezuela had a plan. It was a ta...      0
# 2      2  Sunday on ABC’s “This Week,” while discussing ...      0
# 3      3  AUGUSTA, Me.  —   The beleaguered Republican g...      0
# 4      4    Finian Cunningham has written extensively on...      1
#
#    len of uncleaned news                                         clean_news  \
# 0                   7936  washington sonny perdue telling georgian growi...
# 1                   6112  houston venezuela plan tactical approach desig...
# 2                    425  sunday abc week discussing republican plan rep...
# 3                   6516  augusta beleaguered republican governor maine ...
# 4                   9164  finian cunningham written extensively internat...
#
#    len of cleaned news
# 0                 5246
# 1                 3947
# 2                  259
# 3                 4327
# 4                 6515

# %%
print('Original Length = ',news['len of uncleaned news'].sum())
print('Clean Length =  ', news['len of cleaned news'].sum())
print('Total Reduction = ',news['len of uncleaned news'].sum()-news['len of cleaned news'].sum())
# Out:
# Original Length =  87771325
# Clean Length =   58426659
# Total Reduction =  29344666

# %% [markdown]
# ### MODELLING

# %%
news.head(15)
# Out:
#     index                                               news  label  \
# 0       0  WASHINGTON  —   In Sonny Perdue’s telling, Geo...      0
# 1       1  HOUSTON  —   Venezuela had a plan. It was a ta...      0
# 2       2  Sunday on ABC’s “This Week,” while discussing ...      0
# 3       3  AUGUSTA, Me.  —   The beleaguered Republican g...      0
# 4       4    Finian Cunningham has written extensively on...      1
# 5       6  The State of New Jersey says you can’t eat the...      0
# 6       7  Advocates say prison officials at the Kilby Co...      1
# 7       9  Leave a reply \nToni Emerson – When we fall in...      1
# 8      10  BREAKING: Clinton Fixer Reveals Sick Smear Hil...      1
# 9      11  Home › POLITICS | US NEWS › BLOOMBERG-BACKED P...      1
# 10     12  Populist French presidential candidate Marine ...      0
# 11     13    Donald Trump Is The Candidate For Americans,...      1
# 12     15  Donald J. Trump often cites his undergraduate ...      0
# 13     16  Brexit Ruling Just Latest Tactic to Block Will...      1
# 14     17  Your News Wire \nSouth Koreans are rising up i...      1
#
#     len of uncleaned news                                         clean_news  \
# 0                    7936  washington sonny perdue telling georgian growi...
# 1                    6112  houston venezuela plan tactical approach desig...
# 2                     425  sunday abc week discussing republican plan rep...
# 3                    6516  augusta beleaguered republican governor maine ...
# 4                    9164  finian cunningham written extensively internat...
# 5                    4159  state new jersey say eat fish shellfish lower ...
# 6                    6311  advocate say prison official kilby correctiona...
# 7                    6386  leave reply toni emerson fall love heart becom...
# 8                    1664  breaking clinton fixer reveals sick smear hill...
# 9                    2487  home › politics u news › bloombergbacked penns...
# 10                   1147  populist french presidential candidate marine ...
# 11                   9233  donald trump candidate american special intere...
# 12                   2716  donald j trump often cite undergraduate degree...
# 13                   1038  brexit ruling latest tactic block people novem...
# 14                   5751  news wire south korean rising million demandin...
#
#     len of cleaned news
# 0                  5246
# 1                  3947
# 2                   259
# 3                  4327
# 4                  6515
# 5                  2752
# 6                  3945
# 7                  4239
# 8                  1023
# 9                  1836
# 10                  830
# 11                 5352
# 12                 1797
# 13                  642
# 14                 4005

# %%
X=news['clean_news']
y=news['label']

# %%
tfidf=tf(input='content', encoding='utf-8', lowercase=True,stop_words='english',max_features=7000,ngram_range=(1,3))

# %%
x=tfidf.fit_transform(X).toarray()

# %%
y=np.array(y)
y=y.reshape(-1,1)

# %%
print('shape of x:',x.shape,'\nshape of y:',y.shape)
# Out:
# shape of x: (18285, 7000)
# shape of y: (18285, 1)

# %%
#CHECKING THE SELECTED FEATURE NAMES
tfidf.get_feature_names()[1:30]
# Out:
# ['abandon',
#  'abandoned',
#  'abc',
#  'abc news',
#  'abe',
#  'abedin',
#  'ability',
#  'able',
#  'aboard',
#  'abortion',
#  'abroad',
#  'absence',
#  'absolute',
#  'absolutely',
#  'absurd',
#  'abu',
#  'abuse',
#  'abused',
#  'academic',
#  'academy',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'accepting',
#  'access',
#  'access pipeline',
#  'accessible',
#  'accident']

# %%
F1=[]
ACCURACY = []
PRECESION = []
RECALL = []
RMSE = []
MSE = []
AUC=[]
TPR=[]
FPR=[]
CV_ACC=[]
LOG_LOSS=[]

def acusr(model,x,y):
    max_ac_score=0
    for rst in range(25,180):
        x_train,x_test,y_train,y_test=tts(x,y,test_size=0.30,random_state=rst)
        model.fit(x_train,y_train)
        pred=model.predict(x_test)
        f1=f1_score(pred,y_test)
        acc=accuracy_score(pred,y_test)
        clr=classification_report(y_test,pred)
        conf=confusion_matrix(y_test,pred)
        pre=precision_score(y_test,pred)
        rec=recall_score(y_test,pred)
        mse=mean_squared_error(y_test,pred)
        rmse=np.sqrt(mse)
        auc_scr=roc_auc_score(y_test,pred)
        tpr,fpr,threshold=roc_curve(y_test,pred)
        log = log_loss( y_test,pred)
    
        if acc>max_ac_score:
            max_ac_score=acc
            final_rst=rst
    print("In this",model,'\n\nThe best suited RANDOM SCORE=',final_rst, '\n\nACCURACY SCORE:', max_ac_score)
    print('\nF1 score:',f1)
    print('\nCLASSIFICATION REPORT:\n',clr)
    print('\nCONFUSION MATRIX:\n',conf)
    print('\nPRECISION:\n',pre)
    print('\nRECALL:\n',rec)
    print('\nMEAN SQUARED ERROR:\n',mse)
    print('\nROOT MEAN SQ. ERROR:\n',rmse)
    print('\nAUC_ROC Score:\n',auc_scr)
    print('\nTPR:',tpr,'\nFPR:',fpr)
    print('\nLOG_LOSS:',log)
    
    ACCURACY.append(max_ac_score)
    F1.append(f1)
    PRECESION.append(pre)
    RECALL.append(rec)
    RMSE.append(rmse)
    MSE.append(mse)
    AUC.append(auc_scr)
    TPR.append(tpr)
    FPR.append(fpr)
    LOG_LOSS.append(log)
    
    
#plotting the auc_roc curve
    print('\n\n\t____________________________________________ROC_AUC CURVE_______________________________________________')
    print()
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1)
    plt.figure(figsize=(10,6),dpi=100)
    plt.plot([0,1],[0,1],color='lime',linestyle=":",lw=3)
    plt.plot(tpr,fpr,label="AUC= %0.2f" % auc_scr,color='deepskyblue',lw=3,linestyle='--')
    plt.legend(fancybox=True,shadow=True, fontsize='medium')
    
    plt.xlabel("TPR",weight='bold',fontsize=15)
    plt.ylabel('FPR',weight='bold',fontsize=15)
    plt.title('RECEIVER OPERATING CHARACTERISTICS CURVE\n',size=18,weight='bold',loc='center')
    plt.show()
    
    #plotting confusion matrix
    print('\n\n\t____________________________________________CONFUSION MATRIX___________________________________________\n')
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=1.3)
    plt.figure(figsize=(12,7))
    sns.heatmap(conf,annot=True,fmt='.2f',vmax=1,vmin=0,cmap='nipy_spectral',linewidths=0.8, linecolor='blue')
    plt.title('HEATMAP OF CONFUSION MATRIX\n',size=18,weight='bold',loc='center')
    plt.show()

# %% [markdown]
# ### LOGISTIC REGRESSION

# %%
logi=LogisticRegression()
acusr(logi,x,y)
# Out:
# In this LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)
#
# The best suited RANDOM SCORE= 41
#
# ACCURACY SCORE: 0.9500546846518411
#
# F1 score: 0.9388794567062818
#
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      3118
#            1       0.94      0.93      0.94      2368
#
#     accuracy                           0.95      5486
#    macro avg       0.95      0.95      0.95      5486
# weighted avg       0.95      0.95      0.95      5486
#
#
# CONFUSION MATRIX:
#  [[2986  132]
#  [ 156 2212]]
#
# PRECISION:
#  0.9436860068259386
#
# RECALL:
#  0.9341216216216216
#
# MEAN SQUARED ERROR:
#  0.052497265767407944
#
# ROOT MEAN SQ. ERROR:
#  0.2291228180854276
#
# AUC_ROC Score:
#  0.9458933958011891
#
# TPR: [0.         0.04233483 1.        ]
# FPR: [0.         0.93412162 1.        ]
#
# LOG_LOSS: 1.81321056299582
#
#
# 	____________________________________________ROC_AUC CURVE_______________________________________________
# 	____________________________________________CONFUSION MATRIX___________________________________________

# %%
#using cross_val_score to check for over/under fitting of  LOGISTIC REGRESSION
logi_accuracy=cvs(logi,x,y,scoring='f1',cv=80)
print('THE F1 SCORE AT LOGISTIC MODEL IS=', logi_accuracy.mean())
CV_ACC.append(logi_accuracy.mean())
# Out:
# THE F1 SCORE AT LOGISTIC MODEL IS= 0.9395500786892207

# %% [markdown]
# ### PASSIVE AGGRESSIVE CLASSIFIER

# %%
pac=PassiveAggressiveClassifier()
pac_para={'max_iter': [1000,1100,1200,1500]}
pac_gs=gsv(pac,pac_para,cv=90,n_jobs=-1)
pac_gs.fit(x,y)
print(pac_gs,'\n')
print(pac_gs.best_score_,'\n')
print(pac_gs.best_params_)
# Out:
# GridSearchCV(cv=90, error_score=nan,
#              estimator=PassiveAggressiveClassifier(C=1.0, average=False,
#                                                    class_weight=None,
#                                                    early_stopping=False,
#                                                    fit_intercept=True,
#                                                    loss='hinge', max_iter=1000,
#                                                    n_iter_no_change=5,
#                                                    n_jobs=None,
#                                                    random_state=None,
#                                                    shuffle=True, tol=0.001,
#                                                    validation_fraction=0.1,
#                                                    verbose=0,
#                                                    warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'max_iter': [1000, 1100, 1200, 1500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
#
# 0.9509940757912362
#
# {'max_iter': 1500}

# %%
pac=PassiveAggressiveClassifier(max_iter=1200)
acusr(pac,x,y)
# Out:
# In this PassiveAggressiveClassifier(C=1.0, average=False, class_weight=None,
#                             early_stopping=False, fit_intercept=True,
#                             loss='hinge', max_iter=1200, n_iter_no_change=5,
#                             n_jobs=None, random_state=None, shuffle=True,
#                             tol=0.001, validation_fraction=0.1, verbose=0,
#                             warm_start=False)
#
# The best suited RANDOM SCORE= 106
#
# ACCURACY SCORE: 0.9542471746263216
#
# F1 score: 0.9427850231384097
#
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96      3118
#            1       0.94      0.95      0.94      2368
#
#     accuracy                           0.95      5486
#    macro avg       0.95      0.95      0.95      5486
# weighted avg       0.95      0.95      0.95      5486
#
#
# CONFUSION MATRIX:
#  [[2973  145]
#  [ 127 2241]]
#
# PRECISION:
#  0.9392288348700755
#
# RECALL:
#  0.9463682432432432
#
# MEAN SQUARED ERROR:
#  0.04958075100255195
#
# ROOT MEAN SQ. ERROR:
#  0.2226673550445865
#
# AUC_ROC Score:
#  0.9499320369519616
#
# TPR: [0.         0.04650417 1.        ]
# FPR: [0.         0.94636824 1.        ]
#
# LOG_LOSS: 1.7124796064606433
#
#
# 	____________________________________________ROC_AUC CURVE_______________________________________________
# 	____________________________________________CONFUSION MATRIX___________________________________________

# %%
#using cross_val_score to check for over/under fitting of PASSIVE AGGRESIVE CLASSIFIER
pac_accuracy=cvs(pac,x,y,scoring='f1',cv=80)
print('THE F1 SCORE AT PASSIVE AGGRESIVE CLASSIFIER MODEL IS=', pac_accuracy.mean())
CV_ACC.append(pac_accuracy.mean())
# Out:
# THE F1 SCORE AT PASSIVE AGGRESIVE CLASSIFIER MODEL IS= 0.9420852946107663

# %% [markdown]
# ### MULTINOMIAL NB

# %%
nb=MultinomialNB()
params = {'alpha': [0.1, 0.2, 0.8, 0.9, 1.0]}
mnb = gsv(nb,params,scoring='f1_weighted', cv=50)
mnb.fit(x,y)
print(mnb)
print('\nbest_score=',mnb.best_score_)
print('\nbest_parameters=',mnb.best_params_)
# Out:
# GridSearchCV(cv=50, error_score=nan,
#              estimator=MultinomialNB(alpha=1.0, class_prior=None,
#                                      fit_prior=True),
#              iid='deprecated', n_jobs=None,
#              param_grid={'alpha': [0.1, 0.2, 0.8, 0.9, 1.0]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_weighted', verbose=0)
#
# best_score= 0.901378946956649
#
# best_parameters= {'alpha': 0.1}

# %%
nb=MultinomialNB(alpha=0.1)
acusr(nb,x,y)
# Out:
# In this MultinomialNB(alpha=0.1, class_prior=None, fit_prior=True)
#
# The best suited RANDOM SCORE= 170
#
# ACCURACY SCORE: 0.9104994531534816
#
# F1 score: 0.8838652482269505
#
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92      3118
#            1       0.93      0.84      0.88      2368
#
#     accuracy                           0.90      5486
#    macro avg       0.91      0.90      0.90      5486
# weighted avg       0.91      0.90      0.90      5486
#
#
# CONFUSION MATRIX:
#  [[2968  150]
#  [ 374 1994]]
#
# PRECISION:
#  0.9300373134328358
#
# RECALL:
#  0.8420608108108109
#
# MEAN SQUARED ERROR:
#  0.09551585854903391
#
# ROOT MEAN SQ. ERROR:
#  0.3090564002719146
#
# AUC_ROC Score:
#  0.8969765247126538
#
# TPR: [0.         0.04810776 1.        ]
# FPR: [0.         0.84206081 1.        ]
#
# LOG_LOSS: 3.2990227434465424
#
#
# 	____________________________________________ROC_AUC CURVE_______________________________________________
# 	____________________________________________CONFUSION MATRIX___________________________________________

# %%
#using cross_val_score to check for over/under fitting of MULTINOMIAL NB
nb_accuracy=cvs(nb,x,y,scoring='f1',cv=80)
print('THE F1 SCORE AT MULTINOMIAL NB MODEL IS=', nb_accuracy.mean())
CV_ACC.append(nb_accuracy.mean())
# Out:
# THE F1 SCORE AT MULTINOMIAL NB MODEL IS= 0.8810323425802304

# %% [markdown]
# ### COMPLEMENT NB

# %%
NB_Params = {'alpha': [0.1,  0.9, 1.0]}

cnb = ComplementNB()
cnb_gsv = gsv(cnb, NB_Params, cv=20)
cnb_gsv.fit(x,y)
print(cnb_gsv)
print('\nbest_score=',cnb_gsv.best_score_)
print('\nbest_parameters=',cnb_gsv.best_params_)
# Out:
# GridSearchCV(cv=20, error_score=nan,
#              estimator=ComplementNB(alpha=1.0, class_prior=None, fit_prior=True,
#                                     norm=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'alpha': [0.1, 0.9, 1.0]}, pre_dispatch='2*n_jobs',
#              refit=True, return_train_score=False, scoring=None, verbose=0)
#
# best_score= 0.9082339682653562
#
# best_parameters= {'alpha': 0.1}

# %%
cnb = ComplementNB(alpha=0.1)
acusr(cnb,x,y)
# Out:
# In this ComplementNB(alpha=0.1, class_prior=None, fit_prior=True, norm=False)
#
# The best suited RANDOM SCORE= 176
#
# ACCURACY SCORE: 0.9152387896463726
#
# F1 score: 0.8932414980628497
#
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      3118
#            1       0.91      0.88      0.89      2368
#
#     accuracy                           0.91      5486
#    macro avg       0.91      0.91      0.91      5486
# weighted avg       0.91      0.91      0.91      5486
#
#
# CONFUSION MATRIX:
#  [[2915  203]
#  [ 293 2075]]
#
# PRECISION:
#  0.9108867427568043
#
# RECALL:
#  0.8762668918918919
#
# MEAN SQUARED ERROR:
#  0.09041195771053591
#
# ROOT MEAN SQ. ERROR:
#  0.3006858122867388
#
# AUC_ROC Score:
#  0.9055805274084219
#
# TPR: [0.         0.06510584 1.        ]
# FPR: [0.         0.87626689 1.        ]
#
# LOG_LOSS: 3.1227479785187806
#
#
# 	____________________________________________ROC_AUC CURVE_______________________________________________
# 	____________________________________________CONFUSION MATRIX___________________________________________

# %%
#using cross_val_score to check for over/under fitting of COMPLEMENT NB
cnb_accuracy=cvs(cnb,x,y,scoring='f1',cv=80)
print('THE F1 SCORE AT COMPLEMENT NB MODEL IS=', cnb_accuracy.mean())
CV_ACC.append(cnb_accuracy.mean())
# Out:
# THE F1 SCORE AT COMPLEMENT NB MODEL IS= 0.8910586088108442

# %% [markdown]
# ### RANDOM FOREST CLASSIFIER

# %%
rfc=RandomForestClassifier()
rfc_para={"n_estimators":[400],'max_depth':[3],'criterion':['entropy']}
rfc_gsv=gsv(rfc,rfc_para,cv=30,n_jobs=-1)
rfc_gsv.fit(x,y)
print(rfc_gsv)
print('\nbest score=',rfc_gsv.best_score_)
print('\nbest parameters for RFC=\n',rfc_gsv.best_params_)
# Out:
# GridSearchCV(cv=30, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'criterion': ['entropy'], 'max_depth': [3],
#                          'n_estimators': [400]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
#
# best score= 0.7473857528690767
#
# best parameters for RFC=
#  {'criterion': 'entropy', 'max_depth': 3, 'n_estimators': 400}

# %%
rfc=RandomForestClassifier(n_estimators=400,max_depth=3,criterion='entropy',n_jobs=-1)
acusr(rfc,x,y)
# Out:
# In this RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=3, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=400,
#                        n_jobs=-1, oob_score=False, random_state=None, verbose=0,
#                        warm_start=False)
#
# The best suited RANDOM SCORE= 172
#
# ACCURACY SCORE: 0.7880058330295298
#
# F1 score: 0.6310958118187034
#
# CLASSIFICATION REPORT:
#                precision    recall  f1-score   support
#
#            0       0.71      0.99      0.83      3118
#            1       0.98      0.46      0.63      2368
#
#     accuracy                           0.77      5486
#    macro avg       0.85      0.73      0.73      5486
# weighted avg       0.83      0.77      0.74      5486
#
#
# CONFUSION MATRIX:
#  [[3100   18]
#  [1268 1100]]
#
# PRECISION:
#  0.9838998211091234
#
# RECALL:
#  0.46452702702702703
#
# MEAN SQUARED ERROR:
#  0.23441487422530077
#
# ROOT MEAN SQ. ERROR:
#  0.48416409844731445
#
# AUC_ROC Score:
#  0.7293770478303833
#
# TPR: [0.         0.00577293 1.        ]
# FPR: [0.         0.46452703 1.        ]
#
# LOG_LOSS: 8.0964055480512
#
#
# 	____________________________________________ROC_AUC CURVE_______________________________________________
# 	____________________________________________CONFUSION MATRIX___________________________________________

# %%
rfc_accuracy=cvs(rfc,x,y,scoring='f1',cv=20)

print('THE ACCURACY SCORE AT RFC MODEL IS=', rfc_accuracy.mean())
CV_ACC.append(rfc_accuracy.mean())
# Out:
# THE ACCURACY SCORE AT RFC MODEL IS= 0.591453183638135

# %% [markdown]
# ### RESULT

# %%
model=["LOGISTIC",'PASSIVE AGGRESIVE','MULTINOMIAL NB','COMPLEMENT NB','RANDOM FOREST']
results = pd.DataFrame({"MODEL":model,"F1":F1,'Acuracy':ACCURACY,'Precision': PRECESION ,'Recall': RECALL,
                               'RMSE':RMSE,'MSE':MSE,'AUC':AUC,'TPR':TPR,'FPR':FPR,'LOG_LOSS':LOG_LOSS,"CV_ACCURACY":CV_ACC})
                               
                                
            
results.style.set_properties(**{'background-color':'midnightblue','color': 'lime','border-color': 'darkorange'})
# Out:
# <style  type="text/css" >
#     #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col0 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col1 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col2 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col3 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col4 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col5 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col6 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col7 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col8 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col9 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col10 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow0_col11 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col0 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col1 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col2 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col3 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col4 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col5 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col6 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col7 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col8 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col9 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col10 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow1_col11 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col0 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col1 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col2 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col3 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col4 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col5 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col6 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col7 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col8 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col9 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col10 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow2_col11 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow3_col0 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow3_col1 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow3_col2 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow3_col3 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow3_col4 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow3_col5 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow3_col6 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow3_col7 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow3_col8 {
#             background-color:  midnightblue;
#             color:  lime;
#             border-color:  darkorange;
#         }    #T_3c538d14_3068_11eb_8653_a87eead5317arow3_col9 {
#             background-color:  midnightblue;
#             color:  lime;

# %% [raw]
# ### SAVING RESULT
# Basing on the above obsevation PASSIVE AGGRESIVE CLASSIFIER  is working best with an F1 score  of 0.9448 with out cross validation and F1 score of 0.942897 with cross validation  so selcting it as the final model.

# %%
pac
# Out:
# PassiveAggressiveClassifier(C=1.0, average=False, class_weight=None,
#                             early_stopping=False, fit_intercept=True,
#                             loss='hinge', max_iter=1200, n_iter_no_change=5,
#                             n_jobs=None, random_state=None, shuffle=True,
#                             tol=0.001, validation_fraction=0.1, verbose=0,
#                             warm_start=False)

# %%
joblib.dump(pac,'FAKE_PAC.obj')
# Out:
# ['FAKE_PAC.obj']
